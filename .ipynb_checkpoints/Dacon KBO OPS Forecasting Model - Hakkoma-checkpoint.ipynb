# %% [markdown]
# # 데이콘 (Dacon) KBO OPS Forecasting Model - Hakkoma

# %% [markdown]
# # Index
# - [1.0 Introduction](#10-introduction)
# - [2.0 Data Cleaning](#20-data-cleaning)
# - [3.0 Basic EDA](#30-basic-eda)
#   * [3.1 Distribution of variables](#31-distribution-of-variables)
#   * [3.2 Correlation](#32-correlation)
#   * [3.3 기타 데이터](#33-------)
# - [4.0 Advanced EDA (OPS related)](#40-advanced-eda--ops-related-)
#   * [4.1 Correlation (OPS)](#41-correlation--ops-)
#   * [4.2 Variation](#42-variation)
# - [5.0 Modeling](#50-modeling)
#   * [5.1 Data Preprocessing](#51-data-preprocessing)
#   * [5.2 Machine Learning Modeling (LightGBM)](#52-machine-learning-modeling--lightgbm-)
# - [6.0 Results](#60-results)
#   * [6.1 2018 Model results (Model, Model1)](#61-2018-model-results--model--model1-)
#   * [6.2 2019 Model results (Model2)](#62-2019-model-results--model2-)
# - [7.0 Analysis](#70-analysis)
#   * [7.1 Model (2018 - Overfitting Model) Feature Importance](#71-model--2018---overfitting-model--feature-importance)
#   * [7.2 Model1 (2018 - Accuracy increased Model) Feature Importance](#72-model1--2018---accuracy-increased-model--feature-importance)
#   * [7.3 Model2 (2019 Actual Model) Feature Importance](#73-model2--2019-actual-model--feature-importance)
# - [8.0 Insights](#80-insights)
#   * [8.1 Model (Overfitting)](#81-model--overfitting-)
#   * [8.2 Model2 (2019 Model)](#82-model2--2019-model-)
# - [9.0 Conclusion](#90-conclusion)

# %% [markdown]
# ## 1.0 Introduction

# %% [markdown]
# **Dacon Baseball Data Challenge**
# (https://dacon.io/home)
#
# 현재 한국내의 프로야구는 명실공히, 프로스포츠 최고의 인기 종목이다.
# 야구 종목의 특성상 데이터의 중요성이 강조 되는 가운데, 성적변동성이 해마다 유난히 큰 종목이라,
# 성적예측이 매우 까다로운 종목 중 하나 이다.
#
# 따라서 변동성을 줄이고, 합당한 지표와 변수들을 통해
# 야구 데이터의 불확실성을 줄이고 2019년 타자들의 상반기 성적 예측을 목표로한다.
#
# In these days, Korean Baseball league is the best pro sports in Korea with lots of fans.
# Due to the characteristics of baseball, the significance of the data is raised.
# On top of that, it is hard to determine and predict the player's performance because of the the fluctuation of the player's performance.
#
# Therefore, the objective of this proejct is to reduce the uncertainty with certain variables and right dimensions and
# forecast the first half performance of KBO batters in 2019.

# %% [markdown]
# ## 2.0 Data Cleaning

# %% [markdown]
# 기본적인 데이터를 살펴보고 확인한다.
#
# Look through the dataset and run basic variable checks.

# %%
#import library
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import os

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
#location
os.listdir(os.getcwd())
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'Dacon KBO OPS Forecasting Model - Hakkoma.ipynb',
#  'input',
#  'submission.csv']

# %%
#csv.file read
data = pd.read_csv("input/Regular_Season_Batter.csv")

# %%
#check the data load status
data
# Out:
#       batter_id batter_name  year  team    avg    G   AB   R    H  2B  \
# 0             0        가르시아  2018    LG  0.339   50  183  27   62   9
# 1             1         강경학  2011    한화  0.000    2    1   0    0   0
# 2             1         강경학  2014    한화  0.221   41   86  11   19   2
# 3             1         강경학  2015    한화  0.257  120  311  50   80   7
# 4             1         강경학  2016    한화  0.158   46  101  16   16   3
# 5             1         강경학  2017    한화  0.214   59   84  17   18   2
# 6             1         강경학  2018    한화  0.278   77  245  42   68  11
# 7             2         강구성  2013    NC  0.000    2    2   0    0   0
# 8             2         강구성  2015    NC  0.200    4    5   0    1   1
# 9             2         강구성  2016    NC  0.000    2    3   0    0   0
# 10            2         강구성  2017    NC  0.000    1    1   0    0   0
# 11            2         강구성  2018    NC  0.200    4    5   0    1   1
# ...

# %%
#information of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2454 entries, 0 to 2453
# Data columns (total 29 columns):
# batter_id          2454 non-null int64
# batter_name        2454 non-null object
# year               2454 non-null int64
# team               2454 non-null object
# avg                2428 non-null float64
# G                  2454 non-null int64
# AB                 2454 non-null int64
# R                  2454 non-null int64
# H                  2454 non-null int64
# 2B                 2454 non-null int64
# 3B                 2454 non-null int64
# HR                 2454 non-null int64
# TB                 2454 non-null int64
# RBI                2454 non-null int64
# SB                 2454 non-null int64
# CS                 2454 non-null int64
# BB                 2454 non-null int64
# HBP                2454 non-null int64
# SO                 2454 non-null int64
# GDP                2454 non-null int64
# SLG                2428 non-null float64
# ...

# %% [markdown]
# 현재 데이터에 1루타(1B) 지표가 없으므로 생성한다.
#
# Current dataset, does not cotain the 1B variable. Therefore, need to create 1B variable from H variable

# %%
#Create 1B
data['1B'] = data['H'] - data['2B'] - data['3B'] - data['HR']
#Sequence of 1B
data = data.loc[:,['batter_id','batter_name','year','team','avg',
                'G', 'AB', 'R', 'H','1B','2B', '3B', 'HR', 'TB', 'RBI','SB', 
                'CS', 'BB', 'HBP', 'SO', 'GDP','SLG', 'OBP', 'E','height/weight','year_born','position','career','starting_salary','OPS']]
data
# Out:
#       batter_id batter_name  year  team    avg    G   AB   R    H   1B  \
# 0             0        가르시아  2018    LG  0.339   50  183  27   62   45
# 1             1         강경학  2011    한화  0.000    2    1   0    0    0
# 2             1         강경학  2014    한화  0.221   41   86  11   19   13
# 3             1         강경학  2015    한화  0.257  120  311  50   80   67
# 4             1         강경학  2016    한화  0.158   46  101  16   16   10
# 5             1         강경학  2017    한화  0.214   59   84  17   18   15
# 6             1         강경학  2018    한화  0.278   77  245  42   68   51
# 7             2         강구성  2013    NC  0.000    2    2   0    0    0
# 8             2         강구성  2015    NC  0.200    4    5   0    1    0
# 9             2         강구성  2016    NC  0.000    2    3   0    0    0
# 10            2         강구성  2017    NC  0.000    1    1   0    0    0
# 11            2         강구성  2018    NC  0.200    4    5   0    1    0
# ...

# %% [markdown]
# **기본적 데이터 변수들의 정보는 다음과 같다.**
# **Following table shows the description of variables.**
#
# |**Number**|**Columns**|**Description**|
# |:----:|:----:|:----:|
# |1|batter_id|타자의 고유 아이디|
# |2|batter_name|타자 이름|
# |3|year|년도|
# |4|team|소속팀|
# |5|avg|타율|
# |6|G|출전게임수|
# |7|AB|타수(타석-볼넷-사구-희생번트-희생플라이)|
# |8|R|득점|
# |9|H|안타(1루타+2루타+3루타+홈런)|
# |10|1B|1루타|
# |11|2B|2루타|
# |12|3B|3루타|
# |13|HR|홈런|
# |14|TB|루타 수|
# |15|RBI|타점|
# |16|SB|도루 성공|
# |17|CS|도루 실패|
# |18|BB|볼넷|
# |19|HBP|사구(몸에 맞는 볼)|
# |20|SO|삼진아웃|
# |21|GDP|병살타|
# |22|SLG|장타율|
# |23|OBP|출루율|
# |24|E|에러|
# |25|height/weight|선수의 키/몸무게|
# |26|year_born|선수의 생년월일|
# |27|position|선수의 수비위치|
# |28|career|선수의 커리어|
# |29|starting_salary|선수의 한국프로야구 입단연봉|
# |30|OPS|OPS(OBP+SLG)|
#
# **Note**
# English full description is not provided from the dacon

# %% [markdown]
# 기본적 데이터의 준비가 끝났음으로 다음은 EDA를 진행한다.
#
# As basic data loading and preparation is done, proceed to EDA.

# %% [markdown]
# ## 3.0 Basic EDA

# %% [markdown]
# ### 3.1 Distribution of variables

# %% [markdown]
# #### Year (년도)

# %%
#distribution 'year'
sns.distplot(data['year'])

#simple analytsis of 'year'
data['year'].describe()
# Out:
# count    2454.000000
# mean     2011.614507
# std         4.992833
# min      1993.000000
# 25%      2008.000000
# 50%      2013.000000
# 75%      2016.000000
# max      2018.000000
# Name: year, dtype: float64

# %% [markdown]
# 데이터의 양이 최근 년도로 편중 되있는것으로 확인된며,
# 기본적인 데이터 분석에서도 중간값이 **2011년대**로 나오는것을 확인 할수 있다.
#
# The amount of the data is skewed to recent years and
# **the mean of year shows around 2011**.

# %% [markdown]
# #### B (타수)

# %%
#distribution 'AB'
fig = sns.distplot(data['AB'])
plt.title('Distribution of AB')
plt.show(fig)

#simple analysis 'AB'
data['AB'].describe()
# Out:
# count    2454.000000
# mean      201.514670
# std       169.537029
# min         0.000000
# 25%        38.250000
# 50%       163.000000
# 75%       357.500000
# max       600.000000
# Name: AB, dtype: float64

# %% [markdown]
# 상당수의 타자들이 **100 회 이하의 타석**에 들어선것을 알수 있으며,
# 기본적 데이터 분석에서도 **절반의 선수가 163 타석이하로 들어서는 것**을 알 수 있다.
#
# Remarkable number of batters had **less than 100 AB** and
# basic data description shows that **50% of batter had less than 163** which is lower than expected.

# %% [markdown]
# #### OPS

# %%
#distribution 'OPS'
#OPS의 경우 null 값이 있으므로 해당 null 값들을 제외한다.
fig = sns.distplot(data['OPS'].dropna())
plt.title('Distribution of OPS')
plt.show(fig)

#simple analysis 'OPS'
data['OPS'].describe()
# Out:
# count    2428.000000
# mean        0.649939
# std         0.261634
# min         0.000000
# 25%         0.546000
# 50%         0.688637
# 75%         0.797234
# max         4.000000
# Name: OPS, dtype: float64

# %% [markdown]
# **OPS**의 경우 데이터상 0값을 가지고 있는 선수들이 있으므로 0의 경우 상대적 높게 관측되지만,
# 어느정도 정규분포를 따른다고 이야기 할 수 있다.
#
# **OPS** shows similar to normal distribution but, there are some players with 0 OPS.

# %% [markdown]
# ### 3.2 Correlation

# %%
#OPS vs AB
plt.scatter(data['AB'],data['OPS'])
plt.xlabel("AB")
plt.ylabel("OPS")
plt.title("OPS on AB")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# **OPS**는 **AB(타석)** 수에 **비례하여 상승** 하는것으로 보인다
# 이와 같은 경우는 **성적이 좋은선수 (OPS가 높을 가능성이 높음)** 가
# 꾸준히 타석에 들어서기 때문일 가능성이 제기된다.
#
# **Correlation between AB and OPS shows that the more AB, the higher the OPS.**
# This may happen due to the **player's perofrmance (high chance to have higher OPS)**,
# as better players will have more chance to play.

# %%
#Year vs OPS
plt.scatter(data['year'],data['OPS'])
plt.title('OPS on year')
plt.xlabel('year')
plt.ylabel('OPS')
plt.ylim(-0.2,2.5)
plt.show()

# %% [markdown]
# **OPS**의 **year** 별 분포는 대부분 비슷한 수준으로 형성되있으나,
# 몇몇 outlier 와 2005년 이전에 값의 부재를 확인 할수 있다.

# %%
#'year' vs 'AB'
plt.scatter(data['year'],data['AB'])
plt.title('AB on year')
plt.xlabel('year')
plt.ylabel('AB')
plt.show()

# %% [markdown]
# ### 3.3 기타 데이터

# %% [markdown]
# #### 선수

# %%
#count of unique values
data['batter_name'].nunique()
# Out:
# 345

# %% [markdown]
# **데이터 내에 총 345명의 선수**가 있다.

# %% [markdown]
# #### 포지션(투타)

# %%
#각 포지션 별로 카운트와, 평균값 그래프로 도출
#그룹별로 해서 그래프로 도출하기
#subplot visualisation
plt.figure(figsize=(16,12))
plt.subplots_adjust(hspace=0.4)

plt.tight_layout()
plt.title('OPS & Number of players by Position')
#number of players for each position
#plt.subplot(2,1,1)
data.groupby(['position'])['position'].value_counts().plot(secondary_y=True)

#mean of 'OPS' by each position
#plt.subplot(2,1,2)
data.groupby(['position'])['OPS'].mean().plot.bar()

# %% [markdown]
# **포지션**의 경우
# 내외야 전반적으로, **가장 보편적인 우투우타의 선수가 가장 많은 것으로 관측**되며,
# 포수의 경우 **좌투선수의 데이터가 없는것으로 관측** 된다.
#
# 이는 **포수가 좌투 일 경우**, **도루저지 혹은 송구 시 우타자에 의한 간섭 혹은 방해**가 생기므로,
# **우투가 유리하여 일어난 현상**으로 보인다.
#
# **포지션별 OPS**의 경우,
# **내야수(좌투좌타)가 평균적으로 가장 높은 것**으로 관측되며,
# **내야수(우투양타)가 평균적으로 가장 낮은 것**으로 관측된다.
#
# 포지션의 경우 기재되지 않은 값(null) 값이 다수 존재하므로,
# 관측 대상에서는 제외한다.

# %% [markdown]
# #### Team (팀)

# %%
#Mean of 'OPS' by team
plt.figure(figsize=(16,12))
fig = data.groupby(['team'])['OPS'].mean()

fig.plot.barh()
print(fig)
# Out:
# team
# KIA     0.669274
# KT      0.604821
# LG      0.611325
# NC      0.629626
# OB      0.690377
# SK      0.689050
# 넥센      0.674685
# 두산      0.703056
# 롯데      0.623394
# 삼성      0.649713
# 쌍방울     0.000000
# 우리      0.526328
# 한화      0.617033
# 해태      0.731766
# 현대      0.714416
# 히어로즈    0.560414
# Name: OPS, dtype: float64

# %% [markdown]
# **팀별 OPS**의 경우,
# **해태, 현대 순으로 높은 OPS를 보이며**
# 당시 왜 두팀이 최고의 팀이었는지를 증명하는 것으로 보인다.
#
# **현재 KBO에 참여 하고 있는 팀중**에는 **두산이 가장 높은** 것으로 보인다.

# %% [markdown]
# ## 4.0 Advanced EDA (OPS related)

# %% [markdown]
# 기본적인 EDA 분석후 **세부 EDA**와 **OPS (Target) 관련 변수**들에 대해 알아본다.

# %% [markdown]
# ### 4.1 Correlation (OPS)

# %%
#Correlation of all variables
data_corr = data.corr()

#Correlation heat map
#sns set load
sns.set(style="white")

# Generate a mask for the upper triangle
mask = np.zeros_like(data_corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(data_corr,mask=mask, cmap=cmap, vmin= -1, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
ax.set_title('Correlation')
plt.show()

# %% [markdown]
# **Correlation** 으로 알아보면
#
# **OPS 측면**
# **avg, SLG, OBP** 가 **OPS와 높은 상관관계**를 가지는것을 알수있다.
# 이는 **OPS**가 **SLG**와 **OBP**로 이루어져 잇는것을 통해 설명 가능하며,
# **avg**는 **SLG**와 **OBP**에 영향을 미치기 때문에 위와 같은 결과를 예측 할 수 있다.

# %% [markdown]
# #### Corrleation (OPS on AB)

# %%
#100타석 이하의 OPS
data_ab100 = data.loc[data['AB']<100]
plt.scatter(data_ab100['AB'],data_ab100['OPS'])
plt.title('OPS on AB(<100)')
plt.xlabel('AB')
plt.ylabel('OPS')
plt.show()

#50타석 이전의 경우 변동성이 높으므로 50타석 이상의 선수들로 사용.

# %% [markdown]
# 위의 그래프에서 관촬되었듯이,
# **50타석 이하의 경우, 변동성이 높은 분포**를 보이며,
# 이는 모델의 예측성을 낮추므로,
# **50타석이상의 결과값으로 모델링을 진행**한다.

# %% [markdown]
# ### 4.2 Variation

# %%
#self correlation definition and scatter plot print 
def get_self_corr(var,data=data):
    x=[]
    y=[]
    data_self_corr=data.loc[data['AB']>=50,]
    for name in data_self_corr['batter_name'].unique():
        a=data_self_corr.loc[data_self_corr['batter_name']==name,].sort_values('year')
        k=[]
        for i in a['year'].unique():
            if (a['year']==i+1).sum()==1:
                k.append(i)
        for i in k:
            x.append(a.loc[a['year']==i,var].iloc[0])
            y.append(a.loc[a['year']==i+1,var].iloc[0])
    plt.scatter(x,y)
    plt.title(var)
    
#self correlation definition and scatter plot print 
def get_self_corr_value(var,data=data):
    x=[]
    y=[]
    data_self_corr=data.loc[data['AB']>=50,]
    for name in data_self_corr['batter_name'].unique():
        a=data_self_corr.loc[data_self_corr['batter_name']==name,].sort_values('year')
        k=[]
        for i in a['year'].unique():
            if (a['year']==i+1).sum()==1:
                k.append(i)
        for i in k:
            x.append(a.loc[a['year']==i,var].iloc[0])
            y.append(a.loc[a['year']==i+1,var].iloc[0])
    
    return (pd.Series(x).corr(pd.Series(y))**2)

# %%
#subplot visualisation
plt.figure(figsize=(16,12))
plt.subplots_adjust(hspace=0.4)

plt.tight_layout()

plt.subplot(4,4,1)
get_self_corr('G')

plt.subplot(4,4,2)
get_self_corr('R')

plt.subplot(4,4,3)
get_self_corr('H')

plt.subplot(4,4,4)
get_self_corr('1B')

plt.subplot(4,4,5)
get_self_corr('2B')

plt.subplot(4,4,6)
get_self_corr('3B')

plt.subplot(4,4,7)
get_self_corr('HR')

plt.subplot(4,4,8)
get_self_corr('RBI')

plt.subplot(4,4,9)
get_self_corr('SB')

plt.subplot(4,4,10)
get_self_corr('CS')

plt.subplot(4,4,11)
get_self_corr('BB')

plt.subplot(4,4,12)
get_self_corr('HBP')

plt.subplot(4,4,13)
get_self_corr('SO')

plt.subplot(4,4,14)
get_self_corr('GDP')

plt.subplot(4,4,15)
get_self_corr('avg')

plt.subplot(4,4,16)
get_self_corr('E')

# %%
self_corr_value={}
for i in ['avg','G','R','H','1B','2B','3B','HR','RBI','SB','CS','BB','HBP','SO','GDP','E']:
    self_corr_value[i]=get_self_corr_value(i)
self_corr_value
# Out:
# {'1B': 0.35794510349669717,
#  '2B': 0.3216523588655754,
#  '3B': 0.200111251492148,
#  'BB': 0.45402052125978976,
#  'CS': 0.32940285631650923,
#  'E': 0.3846195701522345,
#  'G': 0.14796062415034458,
#  'GDP': 0.2842618874640301,
#  'H': 0.40021971951430235,
#  'HBP': 0.3079942963187537,
#  'HR': 0.5505976292944423,
#  'R': 0.4249069425378138,
#  'RBI': 0.4591777705797566,
#  'SB': 0.5112843817065359,
#  'SO': 0.3266394990670346,
#  'avg': 0.179871942515314}

# %% [markdown]
# 상대적 신뢰성이 낮은 지표 (변동성이 높은 지표): **avg, GDP, G, 3B**
# 상대적 신뢰성이 높은 지표 (변동성이 낮은 지표): **BB, HR, RBI, SB**
#
# 신뢰성이 낮은 지표는 **운적인 요소가 강한** 지표라고 할수 있으며,
# 신뢰성이 높은 지표는 **운적인 요소가 적은** 지표라고 할수 있다.
#
# 이와같이 변동성이 높은 지표의 경우, 변동성을 줄이는 것이 요구된다.
#
# 따라서,
# 변동성이 높은 지표는 **선수의 누적성적 (Career_performance)** 로 변동성을 줄이는 것이 요구된다.

# %% [markdown]
# ## 5.0 Modeling

# %% [markdown]
# 위에서 알아본 데이터의 성격을 토대로,
# 예측에 사용될 변수들을 만들고, 그에 맞게 데이터를 구성한다.

# %% [markdown]
# ### 5.1 Data Preprocessing

# %%
#extract data for actual use
data_use = data.loc[:,['batter_id','batter_name','year','avg',
                'G', 'AB', 'R', 'H','1B','2B', '3B', 'HR', 'TB', 'RBI','SB', 
                'CS', 'BB', 'HBP', 'SO', 'GDP','SLG', 'OBP', 'E','OPS']]
#AB >= 50
data_use= data_use.loc[data_use['AB']>=50]
data_use.info()

#create 2019 values
create = {}
for i in data_use.columns:
    create[i] = []
for i in data_use.loc[data_use['year']==2018,'batter_name'].unique():
    for j in data_use.columns:
        if j in ['batter_id','batter_name']:
            create[j].append(data_use.loc[data_use['batter_name']==i,j].iloc[0])
        elif j in  ['avg','G', 'AB', 'R', 'H','1B','2B', '3B', 'HR', 'TB', 'RBI','SB',
                    'CS', 'BB', 'HBP', 'SO', 'GDP','SLG', 'OBP', 'E','OPS']:
            create[j].append(0)
        elif j=='year':
            create[j].append(2019)

data_use = pd.concat([data_use,pd.DataFrame(create,columns = data_use.columns)])
data_use.year.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1755 entries, 0 to 2452
# Data columns (total 24 columns):
# batter_id      1755 non-null int64
# batter_name    1755 non-null object
# year           1755 non-null int64
# avg            1755 non-null float64
# G              1755 non-null int64
# AB             1755 non-null int64
# R              1755 non-null int64
# H              1755 non-null int64
# 1B             1755 non-null int64
# 2B             1755 non-null int64
# 3B             1755 non-null int64
# HR             1755 non-null int64
# TB             1755 non-null int64
# RBI            1755 non-null int64
# SB             1755 non-null int64
# CS             1755 non-null int64
# BB             1755 non-null int64
# HBP            1755 non-null int64
# SO             1755 non-null int64
# GDP            1755 non-null int64
# SLG            1755 non-null float64
# OBP            1755 non-null float64
# E              1755 non-null int64
# ...

# %% [markdown]
# **필요한 데이터(사용할 데이터)만을 data_use** 라 칭하였으며,
# 타수(AB)의 경우 **50 타수(AB) 이상 만을 추출**하였다.
#
# 또한, 목표인 **2019년 데이터 관측을 위해서, 2019년 데이터를 생성**하였으며,
# 이는 2019년과 2018년의 데이터를 통해 알수있다.

# %%
#last year performance
for j in ['avg', 'G', 'AB', 'R', 'H','1B', '2B', '3B', 'HR', 'TB', 'RBI', 'SB', 'CS', 'BB', 'HBP', 'SO', 'GDP','SLG', 'OBP', 'E','OPS']:
    lag_1=[]
    for i in range(len(data_use)): 
        if len(data_use.loc[(data_use['batter_name']==data_use['batter_name'].iloc[i])&(data_use['year']==data_use['year'].iloc[i]-1)][j])==0:
            lag_1.append(np.nan)
        else:
            lag_1.append(data_use.loc[(data_use['batter_name']==data_use['batter_name'].iloc[i])&(data_use['year']==data_use['year'].iloc[i]-1)][j].iloc[0])
    
    data_use['lag_1_'+j]=lag_1
print('done :)')
# Out:
# done :)

# %% [markdown]
# **4.2 Variation** 에서 언급되었듯이, 전년도 성적이 고려되야 하므로,
# 전년도 성적에 대한 변수 생성이 진행되었다.

# %%
#Career performance
def Career_performance(name,year,var):
    if (len(data_use.loc[(data_use['batter_name']==name)&(data_use['year']<year-1),'H'])!=0):
        return data_use.loc[(data_use['batter_name']==name)&(data_use['year']<year-1),var].sum()
    else:
        return np.nan

for i in ['G', 'AB', 'R', 'TB', 'RBI', 'SB', 'CS', 'BB', 'HBP', 'SO', 'E', 'OPS']:
    data_use['Career_'+i]=data_use.apply(lambda x: Career_performance(x['batter_name'],x['year'],i),axis=1)
    
print('done :)')
# Out:
# done :)

# %% [markdown]
# **선수의 누적 성적 역시도, 통산 성적을 위해 필요한 변수** 이므로 생성되었다.

# %%
#creating career varaibles
career_avg = []
career_H_AB = []
career_1B_AB = []
career_2B_AB = []
career_3B_AB = []
career_GDP_AB = []
career_SO_AB=[]
career_BB_G=[]
career_R_G=[]
career_TB_G=[]
career_RBI_G=[]
career_SB_G=[]
career_CS_G=[]
career_HBP_G=[]
career_E_G=[]

for i in range (len(data_use)):
    a = data_use.loc[(data_use['batter_name'] == data_use['batter_name'].iloc[i])&(data_use['year']<data_use['year'].iloc[i])]
    career_avg.append((a['avg']*a['AB']).sum()/a['AB'].sum())
    career_H_AB.append(a['H'].sum()/a['AB'].sum())
    career_1B_AB.append(a['1B'].sum()/a['AB'].sum())
    career_2B_AB.append(a['2B'].sum()/a['AB'].sum())
    career_3B_AB.append(a['3B'].sum()/a['AB'].sum())
    career_GDP_AB.append(a['GDP'].sum()/a['AB'].sum())
    #추가
    career_SO_AB.append(a['SO'].sum()/a['AB'].sum())
    career_BB_G.append(a['BB'].sum()/a['G'].sum())
    career_R_G.append(a['R'].sum()/a['G'].sum())
    career_TB_G.append(a['TB'].sum()/a['G'].sum())
    career_RBI_G.append(a['RBI'].sum()/a['G'].sum())
    career_SB_G.append(a['SB'].sum()/a['G'].sum())
    career_CS_G.append(a['CS'].sum()/a['G'].sum())
    career_HBP_G.append(a['HBP'].sum()/a['G'].sum())
    career_E_G.append(a['E'].sum()/a['G'].sum())

data_use['career_avg'] = career_avg
data_use['career_H_AB'] = career_H_AB
data_use['career_1B_AB'] = career_1B_AB
data_use['career_2B_AB'] = career_2B_AB
data_use['career_3B_AB'] = career_3B_AB
data_use['career_GDP_AB'] = career_GDP_AB
#추가
data_use['career_SO_AB']=career_SO_AB
data_use['career_BB_G']= career_BB_G
data_use['career_R_G']= career_R_G
data_use['career_TB_G'] = career_TB_G
data_use['career_RBI_G'] = career_RBI_G
data_use['career_SB_G']= career_SB_G
data_use['career_CS_G']= career_CS_G
data_use['career_HBP_G'] = career_HBP_G
data_use['career_E_G'] = career_E_G

# %% [markdown]
# avg(타율), H(안타), 1B(1루타), 2B(2루타), 3B(3루타), GDP(병살타), SO(삼진아웃) 의 경우 AB(타수) 로 통산 성적을 측정 하였으며,
# BB(볼넷), R(득점), TB(루타 수), RBI(타점), SB(도루 성공), CS(도루 실패), HBP(사구), E(에러) 의 경우 G(출전 게임수) 로 통산 성적을 측정하였다.

# %% [markdown]
# ### 5.2 Machine Learning Modeling (LightGBM)

# %%
#train and test
data_use_train = data_use.loc[data_use['year']<=2017]
data_use_train = data_use_train.loc[~data_use_train['OPS'].isnull()]
data_use_test = data_use.loc[data_use['year']==2018]

# %% [markdown]
# **LightGBM 의 parameter 세팅과 성능**을 알아보기 위해
# **2017년도 까지의 데이터를 가지고 train** 하였으며,
# **2018년도의 데이터로 test** 하였다.
#
# 따라서
# **train data = 2017년도 이전의 데이터
# test data = 2018년도 데이터**  는 아래와 같다.

# %%
#check data_use_train
data_use_train
# Out:
#       batter_id batter_name  year    avg    G   AB   R    H   1B  2B  \
# 2             1         강경학  2014  0.221   41   86  11   19   13   2
# 3             1         강경학  2015  0.257  120  311  50   80   67   7
# 4             1         강경학  2016  0.158   46  101  16   16   10   3
# 5             1         강경학  2017  0.214   59   84  17   18   15   2
# 12          138         백승룡  2005  0.127   39   63   9    8    6   2
# 16          138         백승룡  2011  0.176   38   51   7    9    7   2
# 17          138         백승룡  2012  0.231   33   52   3   12   11   1
# 19          297         진갑용  1997  0.242   95  281  21   68   57   7
# 20          297         진갑용  1998  0.269   88  253  12   68   51  14
# 21          297         진갑용  1999  0.212   68  156  13   33   26   3
# 22          297         진갑용  2000  0.273  114  297  30   81   59  14
# 23          297         진갑용  2001  0.306   89  314  54   96   62  25
# 24          297         진갑용  2002  0.281  133  462  58  130   82  29
# ...

# %%
#check data_use_test
data_use_test
# Out:
#       batter_id batter_name  year    avg    G   AB    R    H   1B  2B  \
# 0             0        가르시아  2018  0.339   50  183   27   62   45   9
# 6             1         강경학  2018  0.278   77  245   42   68   51  11
# 56            4         강민호  2018  0.269  129  427   46  115   79  14
# 57            5         강백호  2018  0.290  138  527  108  153   90  32
# 88            9         강승호  2018  0.255   69  184   14   47   34  10
# 100          11         강진성  2018  0.235   45   68    5   16   13   3
# 105          12         강한울  2018  0.259   83  193   20   50   43   5
# 146          18         고종욱  2018  0.279  102  330   47   92   64  22
# 150          19         구자욱  2018  0.333  116  478  100  159  108  26
# 199          23         권희동  2018  0.283  104  343   43   97   69  19
# 216          24         김강민  2018  0.298   80  235   40   70   42  14
# 238          28         김규민  2018  0.295  104  298   47   88   74   9
# ...

# %%
#light gbm library
import lightgbm as lgb

#model factors (lag, career)
factors = ['lag_1_avg','lag_1_G','lag_1_AB','lag_1_R','lag_1_H','lag_1_1B',
           'lag_1_2B','lag_1_3B','lag_1_HR','lag_1_TB','lag_1_RBI','lag_1_SB','lag_1_CS','lag_1_BB','lag_1_HBP','lag_1_SO','lag_1_GDP',
           'lag_1_SLG','lag_1_OBP','lag_1_E','lag_1_OPS','career_avg','career_H_AB','career_1B_AB','career_2B_AB',
           'career_3B_AB','career_GDP_AB','career_SO_AB','career_BB_G','career_R_G','career_RBI_G','career_HBP_G',
           'career_E_G','career_TB_G','career_CS_G','career_SB_G','career_CS_G']

# %% [markdown]
# 사용할 변수로 전년도 성적과, 통산 성적이 사용되었다.

# %% [markdown]
# #### Model: 2018 Model - Overfitting

# %%
#light gbm parameters
params = {'num_leaves': 50,
         'min_data_in_leaf': 50,
         'objective':'regression',
         'max_depth': 7,
         'learing_rate':0.02,
         'boosting': 'gbdt',
         'feature_fraction':0.7522,
         'bagging_freq':3,
         'bagging_fraction':0.7083,
         'bagging_seed': 11,
         'metric': 'rmse',
         'random_state':2019}

#train_data with lgb dataframe and forecast - over fitting model
train_data = lgb.Dataset(data_use_train[factors],label=data_use_train['OPS'],weight = data_use_train['AB'])
num_rounds = 10000
model = lgb.train(params,train_data, num_rounds, valid_sets = [train_data], verbose_eval = 100, early_stopping_rounds = 200)
forecast = model.predict(data_use_test[factors])
# Out:
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 0.0827998
# [200]	training's rmse: 0.0722302
# [300]	training's rmse: 0.0662985
# [400]	training's rmse: 0.0628811
# [500]	training's rmse: 0.0605692
# [600]	training's rmse: 0.0590848
# [700]	training's rmse: 0.0580192
# [800]	training's rmse: 0.0572657
# [900]	training's rmse: 0.0566842
# [1000]	training's rmse: 0.0562846
# [1100]	training's rmse: 0.055967
# [1200]	training's rmse: 0.0556973
# [1300]	training's rmse: 0.0554723
# [1400]	training's rmse: 0.0553266
# [1500]	training's rmse: 0.0551894
# [1600]	training's rmse: 0.0550715
# [1700]	training's rmse: 0.054979
# [1800]	training's rmse: 0.0549121
# [1900]	training's rmse: 0.0548374
# [2000]	training's rmse: 0.0547936
# [2100]	training's rmse: 0.0547417
# [2200]	training's rmse: 0.0547141
# [2300]	training's rmse: 0.054685
# [2400]	training's rmse: 0.0546487
# [2500]	training's rmse: 0.0546115
# [2600]	training's rmse: 0.0545867
# ...

# %% [markdown]
# **변수의 관계를 알아 보기 위해**, **의도적으로 overfitting 모델을 설정** 하였으며,
# **10000번의 boosting rounds** 를 진행 하였으며, 결과는 아래와 같다.

# %%
#forecast value into data frame
data_check= data_use_test[['batter_id','batter_name','OPS']]
data_check['OPS_forecast']=forecast
data_check['result'] = data_check['OPS']-data_check['OPS_forecast']

#ME of result
print(data_check['result'].mean())
#data frame of result
data_check
# Out:
# -0.0031621074311358873
#       batter_id batter_name    OPS  OPS_forecast    result
# 0             0        가르시아  0.902      0.714829  0.187171
# 6             1         강경학  0.774      0.581377  0.192623
# 56            4         강민호  0.788      0.888231 -0.100231
# 57            5         강백호  0.880      0.714829  0.165171
# 88            9         강승호  0.689      0.618969  0.070031
# 100          11         강진성  0.553      0.714829 -0.161829
# 105          12         강한울  0.612      0.644073 -0.032073
# 146          18         고종욱  0.709      0.737063 -0.028063
# 150          19         구자욱  0.925      0.971754 -0.046754
# 199          23         권희동  0.766      0.814876 -0.048876
# 216          24         김강민  0.906      0.789422  0.116578
# 238          28         김규민  0.730      0.714829  0.015171
# 264          30         김동엽  0.765      0.857470 -0.092470
# 292          33         김동한  0.543      0.642495 -0.099495
# ...

# %% [markdown]
# #### Model1 : 2018 model - accuracy increased

# %%
#light gbm parameters
params = {'num_leaves': 50,
         'min_data_in_leaf': 30,
         'objective':'regression',
         'max_depth': 7,
         'learing_rate':0.02,
         'boosting': 'gbdt',
         'feature_fraction':0.8,
         'bagging_freq':3,
         'bagging_fraction':0.8,
         'bagging_seed': 11,
         'metric': 'rmse',
         'random_state':2019}

#train_data with lgb data frame and forecast - accuracy model
train_data = lgb.Dataset(data_use_train[factors],label=data_use_train['OPS'],weight = data_use_train['AB'])
num_rounds = 2000
model1 = lgb.train(params,train_data, num_rounds, valid_sets = [train_data], verbose_eval = 100, early_stopping_rounds = 200)
forecast1 = model1.predict(data_use_test[factors])
# Out:
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 0.074824
# [200]	training's rmse: 0.064689
# [300]	training's rmse: 0.0601317
# [400]	training's rmse: 0.0580143
# [500]	training's rmse: 0.0567511
# [600]	training's rmse: 0.0560291
# [700]	training's rmse: 0.055559
# [800]	training's rmse: 0.055257
# [900]	training's rmse: 0.055045
# [1000]	training's rmse: 0.0548762
# [1100]	training's rmse: 0.0547664
# [1200]	training's rmse: 0.0547013
# [1300]	training's rmse: 0.0546236
# [1400]	training's rmse: 0.0545718
# [1500]	training's rmse: 0.0545396
# [1600]	training's rmse: 0.0545067
# [1700]	training's rmse: 0.0544844
# [1800]	training's rmse: 0.0544688
# [1900]	training's rmse: 0.0544499
# [2000]	training's rmse: 0.0544447
# Did not meet early stopping. Best iteration is:
# [1997]	training's rmse: 0.05444

# %% [markdown]
# **Overfitting을 해결하기 위해, parameter에 다음을 변경** 하였다.
#
# **min_data_in_a_leaf : 50 -> 30
# feature_fraction: 0.7522 -> 0.8,
# bagging_fraction: 0.7083 -> 0.8**
#
# **변경된 parameter 와 동일한 seed 를 가지고,
# 2000번의 boosting rounds 를 진행** 하였으며, 결과는 아래와 같다.

# %%
#forecast value into data frame
data_check1= data_use_test[['batter_id','batter_name','OPS']]
data_check1['OPS_forecast']=forecast1
data_check1['result'] = data_check1['OPS']-data_check1['OPS_forecast']

#ME of result
print(data_check1['result'].mean())
#data frame of result
data_check1
# Out:
# -0.00024365166238920905
#       batter_id batter_name    OPS  OPS_forecast    result
# 0             0        가르시아  0.902      0.714836  0.187164
# 6             1         강경학  0.774      0.575728  0.198272
# 56            4         강민호  0.788      0.902557 -0.114557
# 57            5         강백호  0.880      0.714836  0.165164
# 88            9         강승호  0.689      0.647191  0.041809
# 100          11         강진성  0.553      0.714836 -0.161836
# 105          12         강한울  0.612      0.628616 -0.016616
# 146          18         고종욱  0.709      0.748359 -0.039359
# 150          19         구자욱  0.925      0.987890 -0.062890
# 199          23         권희동  0.766      0.805006 -0.039006
# 216          24         김강민  0.906      0.684156  0.221844
# 238          28         김규민  0.730      0.714836  0.015164
# 264          30         김동엽  0.765      0.842494 -0.077494
# 292          33         김동한  0.543      0.623593 -0.080593
# ...

# %% [markdown]
# #### *Model2: 2019 Model (Actual Forecasting Model)*

# %%
#2019 model train and test set
data_actual_train = data_use.loc[data_use['year']<=2018]
data_actual_train = data_use_train.loc[~data_use_train['OPS'].isnull()]
data_actual_test = data_use.loc[data_use['year']==2019]

#light gbm parameters
params = {'num_leaves': 50,
         'min_data_in_leaf': 30,
         'objective':'regression',
         'max_depth': 7,
         'learing_rate':0.02,
         'boosting': 'gbdt',
         'feature_fraction':0.8,
         'bagging_freq':3,
         'bagging_fraction':0.8,
         'bagging_seed': 11,
         'metric': 'rmse',
         'random_state':2019}
#train_data into lgb dataset and forecast - 2019 model
train_data = lgb.Dataset(data_actual_train[factors],label=data_actual_train['OPS'],weight = data_actual_train['AB'])
num_rounds = 2000
model2 = lgb.train(params,train_data, num_rounds, valid_sets = [train_data], verbose_eval = 100, early_stopping_rounds = 200)

#forecast
predictions = model2.predict(data_actual_test[factors])
forecast = model2.predict(data_actual_test[factors])
# Out:
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 0.074824
# [200]	training's rmse: 0.064689
# [300]	training's rmse: 0.0601317
# [400]	training's rmse: 0.0580143
# [500]	training's rmse: 0.0567511
# [600]	training's rmse: 0.0560291
# [700]	training's rmse: 0.055559
# [800]	training's rmse: 0.055257
# [900]	training's rmse: 0.055045
# [1000]	training's rmse: 0.0548762
# [1100]	training's rmse: 0.0547664
# [1200]	training's rmse: 0.0547013
# [1300]	training's rmse: 0.0546236
# [1400]	training's rmse: 0.0545718
# [1500]	training's rmse: 0.0545396
# [1600]	training's rmse: 0.0545067
# [1700]	training's rmse: 0.0544844
# [1800]	training's rmse: 0.0544688
# [1900]	training's rmse: 0.0544499
# [2000]	training's rmse: 0.0544447
# Did not meet early stopping. Best iteration is:
# [1997]	training's rmse: 0.05444

# %% [markdown]
# **Model1 과 동일한 환경에서 2018년 데이터 까지 train** 하였으며,
# 결과는 아래와 같다. (2019년 OPS 실 예측지)

# %%
#result dataframe
data_actual_check= data_actual_test[['batter_id','batter_name']]
data_actual_check['OPS'] = forecast
data_actual_check
# Out:
#      batter_id batter_name       OPS
# 0            0        가르시아  0.832871
# 1            1         강경학  0.640580
# 2            4         강민호  0.843105
# 3            5         강백호  0.957529
# 4            9         강승호  0.728201
# 5           11         강진성  0.645737
# 6           12         강한울  0.617857
# 7           18         고종욱  0.699868
# 8           19         구자욱  0.991330
# 9           23         권희동  0.783270
# 10          24         김강민  0.786643
# 11          28         김규민  0.526621
# 12          30         김동엽  0.815695
# 13          33         김동한  0.572204
# 14          35         김문호  0.786271
# 15          36         김민성  0.813315
# 16          38         김민식  0.681778
# 17          39         김민하  0.806774
# 18          40         김사훈  0.678995
# 19          41         김상수  0.697063
# 20          43         김선빈  0.703336
# 21          44         김성욱  0.797470
# 22          45         김성현  0.688412
# 23          46         김성훈  0.809838
# ...

# %% [markdown]
# ## 6.0 Results

# %% [markdown]
# 5.2 에서 완료된 결과는 다음과 같다.

# %% [markdown]
# ### 6.1 2018 Model results (Model, Model1)

# %%
#result of model 1 and 2
plt.figure(figsize=(16,12))
plt.subplots_adjust(hspace=0.4)

plt.subplot(2,1,1)
a = plt.plot(data_check['OPS'], color = 'g')
b = plt.plot(data_check['OPS_forecast'], color = 'r')
plt.plot(data_check1['OPS_forecast'], color = 'b')
plt.title('2018 model - model (training rmse: 0.0543919, 10000 rounds),model1 (training rmse: 0.05444, 2000 rounds)')
plt.legend(['2018 OPS','model','model 1'])

plt.subplot(2,1,2)
plt.plot(data_check['result'], color = 'g')
plt.plot(data_check1['result'],color = 'r')
plt.legend(['result of model','result of model 1'])
plt.title('Error from actual 2018 OPS')
plt.show()

# %% [markdown]
# 전반적인 예측지의 경우 Model1 이 Model이 실제 2018년 OPS에 더욱 가까운 결과 값을 (낮은 ME)를 보여주었으며,
# 이는 위의 그래프에서도 관측되듯, Model1의 결과가 더 좋은 것을 확인 할수 있다.
#
# 하지만, 중간값에서 벗어난 값 (매우 낮거나, 매우 높은), 즉, 변수가 높은 값의 경우는 두 모델 모두,
# 부족한 결과를 나타내었다.
#
# 위와 같이 예측이 극명한 경우,
# 대부분 부상선수로 전년도 값이 커리어 값과 크게 불일치 하거나,
# 통산 성적의 신뢰도가 낮은 신인선수로 나타났다.

# %% [markdown]
# ### 6.2 2019 Model results (Model2)

# %%
#model 2 (2019 model)
plt.figure(figsize=(16,6))
plt.plot(data_actual_check['OPS'], color = 'g')
plt.title('2019 Model - model2')
plt.show()

# %% [markdown]
# 위의 값은 **실 예측치의 값이고, 2018년도 50타수 이상의 선수들의 2019년 OPS 예측값**이다.

# %% [markdown]
# ## 7.0 Analysis

# %% [markdown]
# ### 7.1 Model (2018 - Overfitting Model) Feature Importance

# %%
#Variable importance
#model
lgb.plot_importance(model, height=0.5, max_num_features=100, ignore_zero = False, figsize = (12,10), importance_type ='gain')

# %% [markdown]
# ### 7.2 Model1 (2018 - Accuracy increased Model) Feature Importance

# %%
#model 1
lgb.plot_importance(model1, height=0.5, max_num_features=50, ignore_zero = False, figsize = (12,10), importance_type ='gain')

# %% [markdown]
# ### 7.3 Model2 (2019 Actual Model) Feature Importance

# %%
#model2 
lgb.plot_importance(model2, height=0.5, max_num_features=50, ignore_zero = False, figsize = (12,10), importance_type ='gain')

# %% [markdown]
# **Model 의 경우 Overfitting 에 경우로, 통산타율을 통산 경기당 타점을 높게 평가** 하였으며,
# 운적인 요소가 강하다고 예측했던, **전년도 3루타 변수를 가장 낮게 평가** 하였다.
#
# **Model1과 Model2 의 경우 같은 지표를 사용하여 동일한 결과**를 보여주었으며,
# **통산 경기당 타점과 전년도 OPS값을 높게 평가**하였다.
# 반면, **전년도 3루타 변수를 낮게 평가** 하였지만,
# **Model 과는 다르게 통산 도루 실패의 경우를 가장 낮게 평가**하였다

# %% [markdown]
# ## 8.0 Insights

# %% [markdown]
# 위에 제시된 두 모델의 **Feature Importance 와 OPS의 상관관계**를 통해
# **OPS에 영향을 끼치는 변수**가 무엇인지 알아 본다.

# %% [markdown]
# ### 8.1 Model (Overfitting)

# %% [markdown]
# #### Best 6 Feature Importance

# %%
#model (2018 overfit model)
#best 5
plt.figure(figsize = (16,8))
plt.subplots_adjust(hspace=0.4)

plt.subplot(2,3,1)
plt.title('career_avg')
plt.scatter(data_actual_train['career_avg'],data_actual_train['OPS'], color = 'r')

plt.subplot(2,3,2)
plt.title('career_RBI_G')
plt.scatter(data_actual_train['career_RBI_G'],data_actual_train['OPS'], color = 'b')

plt.subplot(2,3,3)
plt.title('career_H_AB')
plt.scatter(data_actual_train['career_H_AB'],data_actual_train['OPS'], color = 'g')

plt.subplot(2,3,4)
plt.title('lag_1_OPS')
plt.scatter(data_actual_train['lag_1_OPS'],data_actual_train['OPS'], color = 'c')

plt.subplot(2,3,5)
plt.title('lag_1_SLG')
plt.scatter(data_actual_train['lag_1_SLG'],data_actual_train['OPS'], color = 'm')

plt.subplot(2,3,6)
plt.title('career_HBP_G')
plt.scatter(data_actual_train['career_HBP_G'],data_actual_train['OPS'], color = 'y')

plt.show()

# %% [markdown]
# **전반적인 그래프에서 변동성이 적은 관계**를 나타내며 **양의 상관관계**를 보인다.
# 전년도 성적에 비해 **전반적으로 통산 성적이 큰 영향**을 미치는것으로 보이며,
# **전년도 성적으로는 OPS와 SLG가 높은 영향력**이 있는것으로 보인다.
# 하지만 **Career_HBP의 경우는 그렇지 않음**을 보여준다.

# %% [markdown]
# #### Worst 6 Feature Importance

# %%
#worst 6
plt.figure(figsize = (16,8))
plt.subplots_adjust(hspace=0.4)

plt.subplot(2,3,1)
plt.title('lag_1_GDP')
plt.scatter(data_actual_train['lag_1_GDP'],data_actual_train['OPS'], color = 'y')

plt.subplot(2,3,2)
plt.title('lag_1_CS')
plt.scatter(data_actual_train['lag_1_CS'],data_actual_train['OPS'], color = 'k')

plt.subplot(2,3,3)
plt.title('career_CS_G')
plt.scatter(data_actual_train['career_CS_G'],data_actual_train['OPS'], color = 'r')

plt.subplot(2,3,4)
plt.title('lag_1_HBP')
plt.scatter(data_actual_train['lag_1_HBP'],data_actual_train['OPS'], color = 'b')

plt.subplot(2,3,5)
plt.title('lag_1_SB')
plt.scatter(data_actual_train['lag_1_SB'],data_actual_train['OPS'], color = 'g')

plt.subplot(2,3,6)
plt.title('lag_1_3B')
plt.scatter(data_actual_train['lag_1_3B'],data_actual_train['OPS'], color = 'c')

plt.show()

# %% [markdown]
# **전반적인 그래프에서 변동성이 큰 상관관계**를 보이며 뚜렷한 상관관계를 나타내지 않는다.
# 앞서 **3.0, 4.0 에서 나타 났듯이, 운적인 요소가 큰 지표**들이 위와 같은
# 상관관계를 나타낸다.

# %% [markdown]
# ### 8.2 Model2 (2019 Model)

# %% [markdown]
# #### Best 6 Feature Importance

# %%
#model2 - 2019 model
#best 5
plt.figure(figsize = (16,8))
plt.subplots_adjust(hspace=0.4)

plt.subplot(2,3,1)
plt.title('career_RBI_G')
plt.scatter(data_actual_train['career_RBI_G'],data_actual_train['OPS'], color = 'r')

plt.subplot(2,3,2)
plt.title('lag_1_OPS')
plt.scatter(data_actual_train['lag_1_OPS'],data_actual_train['OPS'], color = 'b')

plt.subplot(2,3,3)
plt.title('career_TB_G')
plt.scatter(data_actual_train['career_TB_G'],data_actual_train['OPS'], color = 'g')

plt.subplot(2,3,4)
plt.title('career_2B_AB')
plt.scatter(data_actual_train['career_2B_AB'],data_actual_train['OPS'], color = 'c')

plt.subplot(2,3,5)
plt.title('career_BB_G')
plt.scatter(data_actual_train['career_BB_G'],data_actual_train['OPS'], color = 'm')

plt.subplot(2,3,6)
plt.title('career_2B_AB')
plt.scatter(data_actual_train['career_2B_AB'],data_actual_train['OPS'], color = 'y')

plt.show()

# %% [markdown]
# **Model1 보다 전년도 OPS가 OPS예측에 더 큰 영향**을 미치는 것으로 보이지만,
# **전반적으로는 동일하게 통산 성적이 큰 영향**을 미치는것으로 보인다.
#
# 하지만, **Model1 변수들보다 변동성이 조금 더 큰것**으로 관측된다.

# %% [markdown]
# #### Worst 6 Feature Importance

# %%
#worst 6
plt.figure(figsize = (16,8))
plt.subplots_adjust(hspace=0.4)

plt.subplot(2,3,1)
plt.title('lag_1_R')
plt.scatter(data_actual_train['lag_1_R'],data_actual_train['OPS'], color = 'y')

plt.subplot(2,3,2)
plt.title('lag_1_SB')
plt.scatter(data_actual_train['lag_1_SB'],data_actual_train['OPS'], color = 'k')

plt.subplot(2,3,3)
plt.title('lag_1_H')
plt.scatter(data_actual_train['lag_1_H'],data_actual_train['OPS'], color = 'r')

plt.subplot(2,3,4)
plt.title('lag_1_CS')
plt.scatter(data_actual_train['lag_1_CS'],data_actual_train['OPS'], color = 'b')

plt.subplot(2,3,5)
plt.title('lag_1_3B')
plt.scatter(data_actual_train['lag_1_3B'],data_actual_train['OPS'], color = 'g')

plt.subplot(2,3,6)
plt.title('career_CS_G')
plt.scatter(data_actual_train['career_CS_G'],data_actual_train['OPS'], color = 'c')

plt.show()

# %% [markdown]
# **전반적인 그래프에서 변동성이 큰 상관관계**를 보이며 뚜렷한 상관관계를 나타내지 않는다.
# 하지만, **lag_1_H의 경우 다른 변수들에 비해 비교적 낮은 변동성**을 나타낸다.
# 앞서 **Model1 의 지표들에서 나타 났듯이, 운적인 요소가 큰 지표**들이 위와 같은 상관관계를 나타낸다.

# %% [markdown]
# ## 9.0 Conclusion

# %% [markdown]
# Dacon 에서 주최된 Baseball Data Challenge 에서 제공된 데이터 내에서,
#
# **전년도 성적, 각 지표들의 타수와 출전 게임수로 만들어진 통산 성적**을 통해
#
# 2019년 KBO 타자들의 OPS를 예측해 보았다.
#
# 모델의 결과는,
# **통산 경기당 타점(Career_RBI_G), 전년도 OPS(lag_1_OPS), 통산 루타수(Career_TB_G), 전년도 SLG(lag_1_SLG)**
# 와 같은 지표들이 높은 영향을 끼치는 것으로 나타났다.
#
# 위의 결과는 선수 스카우팅, 신인 드래프트 등과 같은 타자 지표에 사용될 수 있을 것이다.
#
#
# 이번 데이터내에, 희생타 관련 지표들이 빠져있어, 일전에 진행했던, 신인 선수 드래프트 예측에 사용했던,
# WAR, WoBA와 같은 세이버 메트릭스 지표들을 사용하지 못한 점이 아쉬우며, OPS에 깊은 상관관계를 나타내는지에 대해 의문이 남는다.
#
#
# **Ref: 2018 KBO Mock Draft Simulator by sukku04 & Hakkoma**
# (https://github.com/sukku04/KBO_Mock_Draft_Simulator/blob/master/mock_draft.ipynb)

# %%
#the end
#submission
#data_actual_check.to_csv("submission.csv",index=False)
